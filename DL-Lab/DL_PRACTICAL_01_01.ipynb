# %%
# !pip install theano
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 12.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for theano: filename=Theano-1.0.5-py3-none-any.whl size=2668110 sha256=f75f55006d1b4542c353a498ec16641cd933a1c90d40ff9385a4ff9229f3c0ad
#   Stored in directory: /root/.cache/pip/wheels/d9/e6/7d/2267d21a99e4ab8276f976f293b4ff23f50c9d809f4a216ebb
# Successfully built theano
# ...

# %%
import theano
from theano import *
import theano.tensor as T
import numpy as np
import pandas as pd
from theano import function
# Out:
# ---------------------------------------------------------------------------
# NoSectionError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/theano/configparser.py in fetch_val_for_key(key, delete_key)
#     167         try:
# --> 168             return theano_cfg.get(section, option)
#     169         except ConfigParser.InterpolationError:
#
# /usr/lib/python3.10/configparser.py in get(self, section, option, raw, vars, fallback)
#     782         try:
# --> 783             d = self._unify_values(section, vars)
#     784         except NoSectionError:
#
# /usr/lib/python3.10/configparser.py in _unify_values(self, section, vars)
#    1153             if section != self.default_section:
# -> 1154                 raise NoSectionError(section) from None
#    1155         # Update with the entry specific variables
#
# NoSectionError: No section: 'blas'
#
# During handling of the above exception, another exception occurred:
#
# ...
