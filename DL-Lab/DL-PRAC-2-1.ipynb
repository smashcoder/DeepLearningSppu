# %%
# import the necessary packages
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.datasets import mnist
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
import argparse

# %%
# construct the argument parse and parse the arguments
#ap = argparse.ArgumentParser()
#ap.add_argument("-o", "--output", required=True,
#help="path to the output loss/accuracy plot")
#args = vars(ap.parse_args())
# grab the MNIST dataset (if this is your first time using this
# dataset then the 11MB download may take a minute)
print("[INFO] accessing MNIST...")
((trainX, trainY), (testX, testY)) = mnist.load_data()
# each image in the MNIST dataset is represented as a 28x28x1
# image, but in order to apply a standard neural network we must
# first "flatten" the image to be simple list of 28x28=784 pixels
trainX = trainX.reshape((trainX.shape[0], 28 * 28 * 1))
testX = testX.reshape((testX.shape[0], 28 * 28 * 1))
xtest = testX.reshape((testX.shape[0],28,28))
# scale data to the range of [0, 1]
trainX = trainX.astype("float32") / 255.0
testX = testX.astype("float32") / 255.0
# Out:
# [INFO] accessing MNIST...
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
# convert the labels from integers to vectors
lb = LabelBinarizer()
trainY = lb.fit_transform(trainY)
testY = lb.transform(testY)

# %%
# define the 784-256-128-10 architecture using Keras
model = Sequential()
model.add(Dense(256, input_shape=(784,), activation="sigmoid"))
model.add(Dense(128, activation="sigmoid"))
model.add(Dense(10, activation="softmax"))
# train the model using SGD
print("[INFO] training network...")
sgd = SGD(0.01)
model.compile(loss="categorical_crossentropy", optimizer=sgd,
metrics=["accuracy"])
H = model.fit(trainX, trainY, validation_data=(testX, testY),
epochs=100, batch_size=128)
# evaluate the network
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=128)
print(classification_report(testY.argmax(axis=1),
predictions.argmax(axis=1),
target_names=[str(x) for x in lb.classes_]))
# plot the training loss and accuracy
import random

for i in range(0,9):
  r = random.randint(0,100)

plt.imshow(xtest[r])

prediction = model.predict(testX)
print(f"The predicted value is {np.argmax(prediction[r])}")
# Out:
# [INFO] training network...
# Epoch 1/100
# 469/469 [==============================] - 11s 7ms/step - loss: 2.2826 - accuracy: 0.1975 - val_loss: 2.2443 - val_accuracy: 0.1549
# Epoch 2/100
# 469/469 [==============================] - 3s 7ms/step - loss: 2.2119 - accuracy: 0.3883 - val_loss: 2.1719 - val_accuracy: 0.4686
# Epoch 3/100
# 469/469 [==============================] - 2s 4ms/step - loss: 2.1293 - accuracy: 0.5535 - val_loss: 2.0725 - val_accuracy: 0.5538
# Epoch 4/100
# 469/469 [==============================] - 2s 4ms/step - loss: 2.0110 - accuracy: 0.6081 - val_loss: 1.9284 - val_accuracy: 0.6712
# Epoch 5/100
# 469/469 [==============================] - 2s 4ms/step - loss: 1.8424 - accuracy: 0.6541 - val_loss: 1.7304 - val_accuracy: 0.6774
# Epoch 6/100
# 469/469 [==============================] - 2s 3ms/step - loss: 1.6281 - accuracy: 0.6836 - val_loss: 1.5013 - val_accuracy: 0.7074
# Epoch 7/100
# 469/469 [==============================] - 2s 4ms/step - loss: 1.4043 - accuracy: 0.7150 - val_loss: 1.2882 - val_accuracy: 0.7305
# Epoch 8/100
# 469/469 [==============================] - 2s 4ms/step - loss: 1.2118 - accuracy: 0.7436 - val_loss: 1.1173 - val_accuracy: 0.7533
# Epoch 9/100
# 469/469 [==============================] - 2s 5ms/step - loss: 1.0629 - accuracy: 0.7645 - val_loss: 0.9884 - val_accuracy: 0.7743
# Epoch 10/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.9499 - accuracy: 0.7821 - val_loss: 0.8900 - val_accuracy: 0.7969
# Epoch 11/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.8624 - accuracy: 0.7976 - val_loss: 0.8129 - val_accuracy: 0.8054
# Epoch 12/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0
100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2940 - accuracy: 0.9146 - val_loss: 0.2848 - val_accuracy: 0.9188
# Epoch 75/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2928 - accuracy: 0.9148 - val_loss: 0.2836 - val_accuracy: 0.9186
# Epoch 76/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2916 - accuracy: 0.9153 - val_loss: 0.2840 - val_accuracy: 0.9178
# Epoch 77/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2904 - accuracy: 0.9161 - val_loss: 0.2816 - val_accuracy: 0.9188
# Epoch 78/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2893 - accuracy: 0.9162 - val_loss: 0.2804 - val_accuracy: 0.9189
# Epoch 79/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2882 - accuracy: 0.9162 - val_loss: 0.2801 - val_accuracy: 0.9189
# Epoch 80/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2870 - accuracy: 0.9169 - val_loss: 0.2787 - val_accuracy: 0.9193
# Epoch 81/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2859 - accuracy: 0.9171 - val_loss: 0.2773 - val_accuracy: 0.9199
# Epoch 82/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2848 - accuracy: 0.9175 - val_loss: 0.2763 - val_accuracy: 0.9205
# Epoch 83/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2836 - accuracy: 0.9176 - val_loss: 0.2757 - val_accuracy: 0.9200
# Epoch 84/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2826 - accuracy: 0.9176 - val_loss: 0.2745 - val_accuracy: 0.9207
# Epoch 85/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2815 - accuracy: 0.9181 - val_loss: 0.2736 - val_accuracy: 0.9210
# Epoch 86/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2806 - accuracy: 0.9184 - val_loss: 0.2728 - val_accuracy: 0.9209
# Epoch 87/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2794 - accuracy: 0.9188 - val_loss: 0.2725 - val_accuracy: 0.9209
# Epoch 88/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2784 - accuracy: 0.9192 - val_loss: 0.2712 - val_accuracy: 0.9211
# Epoch 89/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2775 - accuracy: 0.9193 - val_loss: 0.2703 - val_accuracy: 0.9221
# Epoch 90/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2765 - accuracy: 0.9196 - val_loss: 0.2691 - val_accuracy: 0.9216
# Epoch 91/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2755 - accuracy: 0.9196 - val_loss: 0.2686 - val_accuracy: 0.9219
# Epoch 92/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2745 - accuracy: 0.9199 - val_loss: 0.2674 - val_accuracy: 0.9220
# Epoch 93/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2735 - accuracy: 0.9203 - val_loss: 0.2663 - val_accuracy: 0.9221
# Epoch 94/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2725 - accuracy: 0.9206 - val_loss: 0.2658 - val_accuracy: 0.9223
# Epoch 95/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2716 - accuracy: 0.9210 - val_loss: 0.2654 - val_accuracy: 0.9223
# Epoch 96/100
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2707 - accuracy: 0.9211 - val_loss: 0.2642 - val_accuracy: 0.9225
# Epoch 97/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2697 - accuracy: 0.9216 - val_loss: 0.2636 - val_accuracy: 0.9229
# Epoch 98/100
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2688 - accuracy: 0.9218 - val_loss: 0.2624 - val_accuracy: 0.9234
# Epoch 99/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2679 - accuracy: 0.9219 - val_loss: 0.2623 - val_accuracy: 0.9232
# Epoch 100/100
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2670 - accuracy: 0.9221 - val_loss: 0.2614 - val_accuracy: 0.9234
# [INFO] evaluating network...
# 79/79 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       980
#            1       0.97      0.97      0.97      1135
#            2       0.92      0.90      0.91      1032
#            3       0.90      0.91      0.91      1010
#            4       0.92      0.93      0.93       982
#            5       0.91      0.86      0.88       892
#            6       0.93      0.94      0.94       958
#            7       0.94      0.92      0.93      1028
#            8       0.89      0.89      0.89       974
#            9       0.90      0.91      0.91      1009
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000
#
# 313/313 [==============================] - 1s 2ms/step
# The predicted value is 6
