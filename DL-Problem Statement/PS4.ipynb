# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# Load the CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize pixel values to be between 0 and 1
x_train, x_test = x_train / 255.0, x_test / 255.0

# Convert labels to one-hot encoding
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

# Build the feedforward neural network model
model = keras.Sequential([
    layers.Flatten(input_shape=(32, 32, 3)),  # Flatten the 32x32x3 input
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.5),  # Add dropout for regularization
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(10, activation='softmax')  # Output layer with 10 classes
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=128, validation_data=(x_test, y_test))

# Evaluate the model on the test dataset
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=2)
print(f"Test accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step
# Epoch 1/10
# 391/391 [==============================] - 19s 45ms/step - loss: 2.1495 - accuracy: 0.1906 - val_loss: 1.9500 - val_accuracy: 0.3122
# Epoch 2/10
# 391/391 [==============================] - 17s 43ms/step - loss: 2.0284 - accuracy: 0.2303 - val_loss: 1.9651 - val_accuracy: 0.3298
# Epoch 3/10
# 391/391 [==============================] - 19s 48ms/step - loss: 1.9903 - accuracy: 0.2451 - val_loss: 1.9044 - val_accuracy: 0.3324
# Epoch 4/10
# 391/391 [==============================] - 17s 42ms/step - loss: 1.9706 - accuracy: 0.2596 - val_loss: 1.9321 - val_accuracy: 0.3390
# Epoch 5/10
# 391/391 [==============================] - 18s 45ms/step - loss: 1.9645 - accuracy: 0.2621 - val_loss: 1.8952 - val_accuracy: 0.3421
# Epoch 6/10
# 391/391 [==============================] - 18s 47ms/step - loss: 1.9582 - accuracy: 0.2655 - val_loss: 1.9495 - val_accuracy: 0.3102
# Epoch 7/10
# 391/391 [==============================] - 17s 43ms/step - loss: 1.9496 - accuracy: 0.2678 - val_loss: 1.9519 - val_accuracy: 0.3033
# Epoch 8/10
# 391/391 [==============================] - 18s 45ms/step - loss: 1.9394 - accuracy: 0.2743 - val_loss: 1.9082 - val_accuracy: 0.3243
# Epoch 9/10
# 391/391 [==============================] - 17s 44ms/step - loss: 1.9472 - accuracy: 0.2708 - val_loss: 1.9379 - val_accuracy: 0.2901
# Epoch 10/10
# 391/391 [==============================] - 17s 42ms/step - loss: 1.9452 - accuracy: 0.2692 - val_loss: 1.9097 - val_accuracy: 0.3266
# 313/313 - 2s - loss: 1.9097 - accuracy: 0.3266 - 2s/epoch - 6ms/step
# Test accuracy: 32.66%
